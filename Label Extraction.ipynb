# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import re
import difflib as dl
import nltk
from sklearn.model_selection import train_test_split

# %%
path_reports = pd.read_csv("Path Reports.csv")
split_reps = pd.read_csv("Chunked Path Reports.csv").drop("Unnamed: 0", axis=1)

# %%
# natural language processing tools

# Negation Processing
def negate_sequence(tokens):
    """
    Detects negations and transforms negated words into "not_" form.
    """
    negation = False
    delims = "?.,!:;"
    result = []
    
    for token in tokens:
        if any(c == token for c in delims):
            negation = False
        
        negated = "not_" + token if negation else token
        result.append(negated)

        if any(neg == token.lower() for neg in ["not", "n't", "no"]):
            negation = not negation   

    return result

# %% [markdown]
# ## Classify Each Biopsy as Invasive or Not

# %%
split_reps
# Out:
#       Patient                                 Biopsy Description  \
# 0           0                    Breast, left, simple mastectomy
# 1           0               Lymph node, sentinel node #1, biopsy
# 2           0               Lymph node, sentinel node #2, biopsy
# 3           0            Lymph node, nonsentinel node #3, biopsy
# 4           0                   Breast, right, simple mastectomy
# 5           1  Left breast, "mass at 12 o'clock 3 cm from nip...
# 6           1  Right breast, 10 o'clock 4 cm from nipple, nee...
# 7           2                  Right axillary contents, excision
# 8           2                       Skin, right axilla, excision
# 9           2                             Right nipple, excision
# 10          3      Right breast, excision of mammographic lesion
# 11          4        Sentinel lymph node #1, left axilla, biopsy
# 12          4        Sentinel lymph node #2, left axilla, biopsy
# 13          4     Nonsentinel lymph node #3, left axilla, biopsy
# 14          4        Right breast, skin-sparing total mastectomy
# 15          4                Right breast, nipple tissue, biopsy
# 16          4         Left breast, skin-sparing total mastectomy
# 17          4                           Left breast, re-excision
# 18          4                        Left breast, nipple, biopsy
# 19          5                                Left breast, biopsy
# 20          5                                     Breast, biopsy
# 21          6              Left breast, 9:30, needle core biopsy
# 22          7                            Left breast, mastectomy
# 23          7       Medial superior margin left breast, excision
# 24          8  Lymph node, right axillary, sentinel node #1, ...
# 25          8                           Right breast, mastectomy
# 26          8  Right breast, upper-inner quadrant, final ante...
# 27          8                  Soft tissue, right nipple, biopsy
# 28          8     Lymph nodes, levels 1 and 2, right, dissection
# 29          9                 Breast, left, "12 o'clock," biopsy
# ...       ...                                                ...
# 6989     3657                Left Breast, Fine Needle Aspiration
# 6990     3658                Left Breast, Fine Needle Aspiration
# 6991     3659                Left Breast, Fine Needle Aspiration
# 6992     3660                Left Breast, Fine Needle Aspiration
# 6993     3661                Left Breast, Fine Needle Aspiration
# 6994     3662                Left Breast, Fine Needle Aspiration
# 6995     3663                Left Breast, Fine Needle Aspiration
# 6996     3664                Left Breast, Fine Needle Aspiration
# 6997     3665                Left Breast, Fine Needle Aspiration
# 6998     3666                Left Breast, Fine Needle Aspiration
# 6999     3667                Left Breast, Fine Needle Aspiration
# 7000     3668                Left Breast, Fine Needle Aspiration
# 7001     3669                Left Breast, Fine Needle Aspiration
# 7002     3670                Left Breast, Fine Needle Aspiration
# 7003     3671                Left Breast, Fine Needle Aspiration
# 7004     3672                Left Breast, Fine Needle Aspiration
# 7005     3673                Left Breast, Fine Needle Aspiration
# 6996                       Adenocarcinoma; see comment.   Left Positive
# 6997                       Adenocarcinoma; see comment.   Left Positive
# 6998                       Adenocarcinoma; see comment.   Left Positive
# 6999                       Adenocarcinoma; see comment.   Left Positive
# 7000                       Adenocarcinoma; see comment.   Left Positive
# 7001                       Adenocarcinoma; see comment.   Left Positive
# 7002                       Adenocarcinoma; see comment.   Left Positive
# 7003                      Adenocarcinoma (see comment).   Left Positive
# 7004                       Adenocarcinoma; see comment.   Left Positive
# 7005                       Adenocarcinoma; see comment.   Left Positive
# 7006                       Adenocarcinoma; see comment.  Right Positive
# 7007            Metastatic adenocarcinoma; see comment.  Right Positive
# 7008                       Adenocarcinoma; see comment.  Right Positive
# 7009            Metastatic adenocarcinoma; see comment.  Right Positive
# 7010                       Adenocarcinoma; see comment.    Positive NOS
# 7011  Metastatic adenocarcinoma in one lymph node (1...    Positive NOS
# 7012  Metastatic adenocarcinoma in one lymph node (1...    Positive NOS
# 7013  1. Invasive ductal carcinoma; see comment. 2. ...    Positive NOS
# 7014  Ductal carcinoma in situ, high grade, solid pa...    Positive NOS
# 7015  1. Severe atypical ductal hyperplasia with mic...    Positive NOS
# 7016  1. Microscopic foci of ductal carcinoma in sit...    Positive NOS
# 7017  Ductal carcinoma in situ, nuclear grade 2-3; s...    Positive NOS
# 7018  Small foci of atypical ductal hyperplasia, no ...    Positive NOS
#
#      Laterality Biopsy Source
# 0          left        breast
# 1            na    lymph node
# 2            na    lymph node
# 3            na    lymph node
# 4         right        breast
# 5          left        breast
# 6         right        breast
# 7         right        uterus
# 8         right          skin
# 9         right        breast
# 10        right        breast
# 11         left    lymph node
# 12         left    lymph node
# 13         left    lymph node
# 14        right        breast
# 15        right        breast
# 16         left        breast
# 17         left        breast
# 18         left        breast
# 19         left        breast
# 20           na        breast
# 21         left        breast
# 22         left        breast
# 23         left        breast
# 24        right    lymph node
# 25        right        breast
# 26        right        breast
# 27        right        breast
# 28        right    lymph node
# 29         left        breast
# ...         ...           ...
# 6989       left        breast
# 6990       left        breast
# 6991       left        breast
# 6992       left        breast
# 6993       left        breast
# 6994       left        breast
# 6995       left        breast
# 6996       left        breast
# 6997       left        breast
# 6998       left        breast
# 6999       left        breast
# 7000       left        breast
# 7001       left        breast
# 7002       left        breast
# 7003       left        breast
# 7004       left        breast
# 7005       left        breast
# 7006      right        breast
# 7007      right    lymph node
# 7008      right        breast
# 7009      right    lymph node
# 7010         na        breast
# 7011         na    lymph node
# 7012         na    lymph node
# 7013         na        breast
# 7014         na        breast
# 7015         na        breast
# 7016         na        breast
# 7017         na        breast
# 7018         na            na
#
# [7019 rows x 6 columns]

# %%
def classify_invasive(pathRep):
    pathRep = ' '.join(negate_sequence(nltk.word_tokenize(pathRep.lower())))
    obs = re.split(re.compile(r"[0-9]\."), pathRep)
    if len(obs) > 1:
        obs = obs[1:]
    
    obs = [' ' + ob for ob in obs] # pad with spaces to match markers that come at beginning of strings
    
    classes = []
    for ob in obs:
        inv_marker = re.compile(" invasive| infiltrating")
        ben_marker = re.compile(" in situ| benign| fibroadenoma")
        if re.search(inv_marker, ob):
            classes.append("invasive")
        elif re.search(ben_marker, ob):
            classes.append("benign")
        else:
            classes.append("normal")
    return classes

# %%
re.split(re.compile(r"[0-9]\."), "3. hello")
# Out:
# ['', ' hello']

# %%
split_reps["Invasive/Benign"] = split_reps["Path Report"].apply(classify_invasive)
split_reps
# Out:
#       Patient                                 Biopsy Description  \
# 0           0                    Breast, left, simple mastectomy
# 1           0               Lymph node, sentinel node #1, biopsy
# 2           0               Lymph node, sentinel node #2, biopsy
# 3           0            Lymph node, nonsentinel node #3, biopsy
# 4           0                   Breast, right, simple mastectomy
# 5           1  Left breast, "mass at 12 o'clock 3 cm from nip...
# 6           1  Right breast, 10 o'clock 4 cm from nipple, nee...
# 7           2                  Right axillary contents, excision
# 8           2                       Skin, right axilla, excision
# 9           2                             Right nipple, excision
# 10          3      Right breast, excision of mammographic lesion
# 11          4        Sentinel lymph node #1, left axilla, biopsy
# 12          4        Sentinel lymph node #2, left axilla, biopsy
# 13          4     Nonsentinel lymph node #3, left axilla, biopsy
# 14          4        Right breast, skin-sparing total mastectomy
# 15          4                Right breast, nipple tissue, biopsy
# 16          4         Left breast, skin-sparing total mastectomy
# 17          4                           Left breast, re-excision
# 18          4                        Left breast, nipple, biopsy
# 19          5                                Left breast, biopsy
# 20          5                                     Breast, biopsy
# 21          6              Left breast, 9:30, needle core biopsy
# 22          7                            Left breast, mastectomy
# 23          7       Medial superior margin left breast, excision
# 24          8  Lymph node, right axillary, sentinel node #1, ...
# 25          8                           Right breast, mastectomy
# 26          8  Right breast, upper-inner quadrant, final ante...
# 27          8                  Soft tissue, right nipple, biopsy
# 28          8     Lymph nodes, levels 1 and 2, right, dissection
# 29          9                 Breast, left, "12 o'clock," biopsy
# ...       ...                                                ...
# 6989     3657                Left Breast, Fine Needle Aspiration
# 6990     3658                Left Breast, Fine Needle Aspiration
# 6991     3659                Left Breast, Fine Needle Aspiration
# 6992     3660                Left Breast, Fine Needle Aspiration
# 6993     3661                Left Breast, Fine Needle Aspiration
# 6994     3662                Left Breast, Fine Needle Aspiration
# 6995     3663                Left Breast, Fine Needle Aspiration
# 6996     3664                Left Breast, Fine Needle Aspiration
# 6997     3665                Left Breast, Fine Needle Aspiration
# 6998     3666                Left Breast, Fine Needle Aspiration
# 6999     3667                Left Breast, Fine Needle Aspiration
# 7000     3668                Left Breast, Fine Needle Aspiration
# 7001     3669                Left Breast, Fine Needle Aspiration
# 7002     3670                Left Breast, Fine Needle Aspiration
# 7003     3671                Left Breast, Fine Needle Aspiration
# 7004     3672                Left Breast, Fine Needle Aspiration
# 7005     3673                Left Breast, Fine Needle Aspiration
# 7006     3674               Right Breast, Fine Needle Aspiration
# 7007     3674  Right Axillary Lymph Node, Fine Needle Aspiration
# 7008     3675               Right Breast, Fine Needle Aspiration
# 7009     3675  Right Axillary Lymph Node, Fine Needle Aspiration
# 7010     3676    Subareolar Mass, Breast, Fine Needle Aspiration
# 7011     3677                     Lymph node, "sentinel", biopsy
# 7012     3677                  Lymph node, "sentinel #2", biopsy
# 7004                       Adenocarcinoma; see comment.   Left Positive
# 7005                       Adenocarcinoma; see comment.   Left Positive
# 7006                       Adenocarcinoma; see comment.  Right Positive
# 7007            Metastatic adenocarcinoma; see comment.  Right Positive
# 7008                       Adenocarcinoma; see comment.  Right Positive
# 7009            Metastatic adenocarcinoma; see comment.  Right Positive
# 7010                       Adenocarcinoma; see comment.    Positive NOS
# 7011  Metastatic adenocarcinoma in one lymph node (1...    Positive NOS
# 7012  Metastatic adenocarcinoma in one lymph node (1...    Positive NOS
# 7013  1. Invasive ductal carcinoma; see comment. 2. ...    Positive NOS
# 7014  Ductal carcinoma in situ, high grade, solid pa...    Positive NOS
# 7015  1. Severe atypical ductal hyperplasia with mic...    Positive NOS
# 7016  1. Microscopic foci of ductal carcinoma in sit...    Positive NOS
# 7017  Ductal carcinoma in situ, nuclear grade 2-3; s...    Positive NOS
# 7018  Small foci of atypical ductal hyperplasia, no ...    Positive NOS
#
#      Laterality Biopsy Source  \
# 0          left        breast
# 1            na    lymph node
# 2            na    lymph node
# 3            na    lymph node
# 4         right        breast
# 5          left        breast
# 6         right        breast
# 7         right        uterus
# 8         right          skin
# 9         right        breast
# 10        right        breast
# 11         left    lymph node
# 12         left    lymph node
# 13         left    lymph node
# 14        right        breast
# 15        right        breast
# 16         left        breast
# 17         left        breast
# 18         left        breast
# 19         left        breast
# 20           na        breast
# 21         left        breast
# 22         left        breast
# 23         left        breast
# 24        right    lymph node
# 25        right        breast
# 26        right        breast
# 27        right        breast
# 28        right    lymph node
# 29         left        breast
# ...         ...           ...
# 6989       left        breast
# 6990       left        breast
# 6991       left        breast
# 6992       left        breast
# 6993       left        breast
# 6994       left        breast
# 6995       left        breast
# 6996       left        breast
# 6997       left        breast
# 6998       left        breast
# 6999       left        breast
# 7000       left        breast
# 7001       left        breast
# 7002       left        breast
# 7003       left        breast
# 7004       left        breast
# 7005       left        breast
# 7006      right        breast
# 7007      right    lymph node
# 7008      right        breast
# 7009      right    lymph node
# 7010         na        breast
# 7011         na    lymph node
# 7012         na    lymph node
# 7013         na        breast
# 7014         na        breast
# 7015         na        breast
# 7016         na        breast
# 7017         na        breast
# 7018         na            na
#
#                                         Invasive/Benign
# 0            [invasive, benign, benign, normal, normal]
# 1                                              [normal]
# 2                                              [normal]
# 3                                              [normal]
# 4                              [normal, normal, normal]
# 5                                    [invasive, benign]
# 6                                              [benign]
# 7                                              [normal]
# 8                                              [normal]
# 9                                      [normal, normal]
# 10    [benign, normal, normal, normal, benign, norma...
# 11                                             [normal]
# 12                                             [normal]
# 13                                             [normal]
# 14                     [normal, normal, normal, normal]
# 15                                             [normal]
# 16    [invasive, normal, normal, normal, normal, nor...
# 17                                             [normal]
# 18                                             [normal]
# 19                           [invasive, normal, normal]
# 20                                             [normal]
# 21                                             [normal]
# 22                     [benign, normal, benign, benign]
# 23                                             [normal]
# 24                                     [normal, normal]
# 25                     [normal, benign, benign, benign]
# 26                                             [benign]
# 27                                             [benign]
# 28                                             [normal]
# 29                                             [benign]
# ...                                                 ...
# 6989                                           [normal]
# 6990                                           [normal]
# 6991                                           [normal]
# 6992                                           [normal]
# 6993                                           [normal]
# 6994                                           [normal]
# 6995                                           [normal]
# 6996                                           [normal]
# 6997                                           [normal]
# 6998                                           [normal]
# 6999                                           [normal]
# 7000                                           [normal]
# 7001                                           [normal]
# 7002                                           [normal]
# 7003                                           [normal]
# 7004                                           [normal]
# 7005                                           [normal]
# 7006                                           [normal]
# 7007                                           [normal]
# 7008                                           [normal]
# 7009                                           [normal]
# 7010                                           [normal]
# 7011                                           [normal]
# 7012                                           [normal]
# 7013                                 [invasive, benign]
# 7014                                           [benign]
# 7015                                   [normal, normal]
# 7016           [benign, normal, normal, benign, normal]
# 7017                                           [benign]
# 7018                                           [normal]
#
# [7019 rows x 7 columns]

# %%
split_reps.iloc[0]["Path Report"]
# Out:
# '1. Invasive lobular carcinoma in a background of lobular carcinoma in situ, negative margins; see comment. 2. Ductal carcinoma in situ, grade 2, negative margins; see comment. 3. Hyalinized fibroadenoma, radial scar and fibrocystic changes. 4. Biopsy site changes. 5. Nipple with no significant pathologic abnormality.'

# %%
num_inv = sum(["invasive" in split_rep for split_rep in split_reps["Invasive/Benign"]])
num_ben = sum(["benign" in split_rep for split_rep in split_reps["Invasive/Benign"]])
num_norm = sum(["normal" in split_rep for split_rep in split_reps["Invasive/Benign"]])
num_inv, num_ben, num_norm
# Out:
# (692, 2961, 5253)

# %%
def classify_distribution(pathRep):
    pathRep = ' '.join(negate_sequence(nltk.word_tokenize(pathRep.lower())))
    obs = re.split(re.compile(r"[0-9]\."), pathRep)
    if len(obs) > 1:
        obs = obs[1:]
    obs = [' ' + ob for ob in obs] # pad with spaces to match markers that come at beginning of strings
    
    classes = []
    
    lob_marker = re.compile(" lobul[a-zA-Z]*")
    duct_marker = re.compile(" duct[a-zA-Z]*")
    for ob in obs:
        
        if re.search(lob_marker, ob) and re.search(duct_marker, ob):
            classes.append("lobular/ductal")
        elif re.search(lob_marker, ob):
            classes.append("lobular")
        elif re.search(duct_marker, ob):
            classes.append("ductal")
        else:
            classes.append("none")
    return classes

# %%
split_reps["Distribution"] = split_reps["Path Report"].apply(classify_distribution)
split_reps
# Out:
#       Patient                                 Biopsy Description  \
# 0           0                    Breast, left, simple mastectomy
# 1           0               Lymph node, sentinel node #1, biopsy
# 2           0               Lymph node, sentinel node #2, biopsy
# 3           0            Lymph node, nonsentinel node #3, biopsy
# 4           0                   Breast, right, simple mastectomy
# 5           1  Left breast, "mass at 12 o'clock 3 cm from nip...
# 6           1  Right breast, 10 o'clock 4 cm from nipple, nee...
# 7           2                  Right axillary contents, excision
# 8           2                       Skin, right axilla, excision
# 9           2                             Right nipple, excision
# 10          3      Right breast, excision of mammographic lesion
# 11          4        Sentinel lymph node #1, left axilla, biopsy
# 12          4        Sentinel lymph node #2, left axilla, biopsy
# 13          4     Nonsentinel lymph node #3, left axilla, biopsy
# 14          4        Right breast, skin-sparing total mastectomy
# 15          4                Right breast, nipple tissue, biopsy
# 16          4         Left breast, skin-sparing total mastectomy
# 17          4                           Left breast, re-excision
# 14        right        breast
# 15        right        breast
# 16         left        breast
# 17         left        breast
# 18         left        breast
# 19         left        breast
# 20           na        breast
# 21         left        breast
# 22         left        breast
# 23         left        breast
# 24        right    lymph node
# 25        right        breast
# 26        right        breast
# 27        right        breast
# 28        right    lymph node
# 29         left        breast
# ...         ...           ...
# 6989       left        breast
# 6990       left        breast
# 6991       left        breast
# 6992       left        breast
# 6993       left        breast
# 6994       left        breast
# 6995       left        breast
# 6996       left        breast
# 6997       left        breast
# 6998       left        breast
# 6999       left        breast
# 7000       left        breast
# 7001       left        breast
# 7002       left        breast
# 7003       left        breast
# 7004       left        breast
# 7005       left        breast
# 7006      right        breast
# 7007      right    lymph node
# 7008      right        breast
# 7009      right    lymph node
# 7010         na        breast
# 7011         na    lymph node
# 7012         na    lymph node
# 7013         na        breast
# 7014         na        breast
# 7015         na        breast
# 7016         na        breast
# 7017         na        breast
# 7018         na            na
#
#                                         Invasive/Benign  \
# 0            [invasive, benign, benign, normal, normal]
# 1                                              [normal]
# 2                                              [normal]
# 3                                              [normal]
# 4                              [normal, normal, normal]
# 5                                    [invasive, benign]
# 6                                              [benign]
# 7                                              [normal]
# 8                                              [normal]
# 9                                      [normal, normal]
# 10    [benign, normal, normal, normal, benign, norma...
# 11                                             [normal]
# 12                                             [normal]
# 13                                             [normal]
# 14                     [normal, normal, normal, normal]
# 15                                             [normal]
# 16    [invasive, normal, normal, normal, normal, nor...
# 17                                             [normal]
# 18                                             [normal]
# 19                           [invasive, normal, normal]
# 20                                             [normal]
# 21                                             [normal]
# 22                     [benign, normal, benign, benign]
# 23                                             [normal]
# 24                                     [normal, normal]
# 25                     [normal, benign, benign, benign]
# 26                                             [benign]
# 27                                             [benign]
# 28                                             [normal]
# 29                                             [benign]
# ...                                                 ...
# 6989                                           [normal]
# 6990                                           [normal]
# 6991                                           [normal]
# 6992                                           [normal]
# 6993                                           [normal]
# 6994                                           [normal]
# 6995                                           [normal]
# 6996                                           [normal]
# 6997                                           [normal]
# 6998                                           [normal]
# 6999                                           [normal]
# 7000                                           [normal]
# 7001                                           [normal]
# 7002                                           [normal]
# 7003                                           [normal]
# 7004                                           [normal]
# 7005                                           [normal]
# 7006                                           [normal]
# 7007                                           [normal]
# 7008                                           [normal]
# 7009                                           [normal]
# 7010                                           [normal]
# 7011                                           [normal]
# 7012                                           [normal]
# 7013                                 [invasive, benign]
# 7014                                           [benign]
# 7015                                   [normal, normal]
# 7016           [benign, normal, normal, benign, normal]
# 7017                                           [benign]
# 7018                                           [normal]
#
#                                          Distribution
# 0                 [lobular, ductal, none, none, none]
# 1                                              [none]
# 2                                              [none]
# 3                                              [none]
# 4                                  [none, none, none]
# 5                                    [ductal, ductal]
# 6                                              [none]
# 7                                              [none]
# 8                                              [none]
# 9                                      [ductal, none]
# 10       [ductal, none, none, none, none, none, none]
# 11                                             [none]
# 12                                             [none]
# 13                                             [none]
# 14                        [none, lobular, none, none]
# 15                                             [none]
# 16    [ductal, none, lobular, none, none, none, none]
# 17                                             [none]
# 18                                             [none]
# 19                               [ductal, none, none]
# 20                                           [ductal]
# 21                                             [none]
# 22                      [ductal, none, lobular, none]
# 23                                             [none]
# 24                                       [none, none]
# 25                       [none, ductal, none, ductal]
# 26                                             [none]
# 27                                             [none]
# 28                                             [none]
# 29                                          [lobular]
# ...                                               ...
# 6989                                           [none]
# 6990                                           [none]
# 6991                                           [none]
# 6992                                           [none]
# 6993                                           [none]
# 6994                                           [none]
# 6995                                           [none]
# 6996                                           [none]
# 6997                                           [none]
# 6998                                           [none]
# 6999                                           [none]
# 7000                                           [none]
# 7001                                           [none]
# 7002                                           [none]
# 7003                                           [none]
# 7004                                           [none]
# 7005                                           [none]
# 7006                                           [none]
# 7007                                           [none]
# 7008                                           [none]
# 7009                                           [none]
# 7010                                           [none]
# 7011                                           [none]
# 7012                                           [none]
# 7013                                 [ductal, ductal]
# 7014                                         [ductal]
# 7015                                 [ductal, ductal]
# 7016     [ductal, lobular/ductal, none, ductal, none]
# 7017                                         [ductal]
# 7018                                         [ductal]
#
# [7019 rows x 8 columns]

# %%
duct_marker = re.compile(" duct[a-zA-Z]*")
re.search(duct_marker, 'ductal carcinoma in situ, nuclear grade 2-3; see comment.')#, split_reps.iloc[7017]["Invasive/Benign"]

# %%
def summarize_cancer_label(type_lst, dist_lst):
    if "invasive" in type_lst:
        inds = [i for i in range(len(type_lst)) if type_lst[i] == "invasive"]
        dists = [dist_lst[i] for i in inds if dist_lst[i] != "none"]
        labels = ["invasive " + dist + " carcinoma" for dist in dists]
        return set(labels)
    elif "benign" in type_lst:
        inds = [i for i in range(len(type_lst)) if type_lst[i] == "benign"]
        dists = [dist_lst[i] for i in inds if dist_lst[i] != "none"]
        labels = ["benign " + dist + " carcinoma" for dist in dists]
        return set(labels)
    else:
        return set(["normal"])

# %%
labels = []
for i in range(split_reps.shape[0]):
    type_lst = split_reps.iloc[i]["Invasive/Benign"]
    dist_lst = split_reps.iloc[i]["Distribution"]
    labels.append(summarize_cancer_label(type_lst, dist_lst))
split_reps["Summarized Labels"] = labels
split_reps
# Out:
#       Patient                                 Biopsy Description  \
# 0           0                    Breast, left, simple mastectomy
# 1           0               Lymph node, sentinel node #1, biopsy
# 2           0               Lymph node, sentinel node #2, biopsy
# 3           0            Lymph node, nonsentinel node #3, biopsy
# 4           0                   Breast, right, simple mastectomy
# 5           1  Left breast, "mass at 12 o'clock 3 cm from nip...
# 6           1  Right breast, 10 o'clock 4 cm from nipple, nee...
# 7           2                  Right axillary contents, excision
# 8           2                       Skin, right axilla, excision
# 9           2                             Right nipple, excision
# 10          3      Right breast, excision of mammographic lesion
# 11          4        Sentinel lymph node #1, left axilla, biopsy
# 12          4        Sentinel lymph node #2, left axilla, biopsy
# 13          4     Nonsentinel lymph node #3, left axilla, biopsy
# 14          4        Right breast, skin-sparing total mastectomy
# 15          4                Right breast, nipple tissue, biopsy
# 16          4         Left breast, skin-sparing total mastectomy
# 17          4                           Left breast, re-excision
# 13         left    lymph node
# 14        right        breast
# 15        right        breast
# 16         left        breast
# 17         left        breast
# 18         left        breast
# 19         left        breast
# 20           na        breast
# 21         left        breast
# 22         left        breast
# 23         left        breast
# 24        right    lymph node
# 25        right        breast
# 26        right        breast
# 27        right        breast
# 28        right    lymph node
# 29         left        breast
# ...         ...           ...
# 6989       left        breast
# 6990       left        breast
# 6991       left        breast
# 6992       left        breast
# 6993       left        breast
# 6994       left        breast
# 6995       left        breast
# 6996       left        breast
# 6997       left        breast
# 6998       left        breast
# 6999       left        breast
# 7000       left        breast
# 7001       left        breast
# 7002       left        breast
# 7003       left        breast
# 7004       left        breast
# 7005       left        breast
# 7006      right        breast
# 7007      right    lymph node
# 7008      right        breast
# 7009      right    lymph node
# 7010         na        breast
# 7011         na    lymph node
# 7012         na    lymph node
# 7013         na        breast
# 7014         na        breast
# 7015         na        breast
# 7016         na        breast
# 7017         na        breast
# 7018         na            na
#
#                                         Invasive/Benign  \
# 0            [invasive, benign, benign, normal, normal]
# 1                                              [normal]
# 2                                              [normal]
# 3                                              [normal]
# 4                              [normal, normal, normal]
# 5                                    [invasive, benign]
# 6                                              [benign]
# 7                                              [normal]
# 8                                              [normal]
# 9                                      [normal, normal]
# 10    [benign, normal, normal, normal, benign, norma...
# 11                                             [normal]
# 12                                             [normal]
# 13                                             [normal]
# 14                     [normal, normal, normal, normal]
# 15                                             [normal]
# 16    [invasive, normal, normal, normal, normal, nor...
# 17                                             [normal]
# 18                                             [normal]
# 19                           [invasive, normal, normal]
# 20                                             [normal]
# 21                                             [normal]
# 22                     [benign, normal, benign, benign]
# 23                                             [normal]
# 24                                     [normal, normal]
# 25                     [normal, benign, benign, benign]
# 26                                             [benign]
# 27                                             [benign]
# 28                                             [normal]
# 29                                             [benign]
# ...                                                 ...
# 6989                                           [normal]
# 6990                                           [normal]
# 6991                                           [normal]
# 6992                                           [normal]
# 6993                                           [normal]
# 6994                                           [normal]
# 6995                                           [normal]
# 6996                                           [normal]
# 6997                                           [normal]
# 6998                                           [normal]
# 6999                                           [normal]
# 7000                                           [normal]
# 7001                                           [normal]
# 7002                                           [normal]
# 7003                                           [normal]
# 7004                                           [normal]
# 7005                                           [normal]
# 7006                                           [normal]
# 7007                                           [normal]
# 7008                                           [normal]
# 7009                                           [normal]
# 7010                                           [normal]
# 7011                                           [normal]
# 7012                                           [normal]
# 7013                                 [invasive, benign]
# 7014                                           [benign]
# 7015                                   [normal, normal]
# 7016           [benign, normal, normal, benign, normal]
# 7017                                           [benign]
# 7018                                           [normal]
#
#                                          Distribution  \
# 0                 [lobular, ductal, none, none, none]
# 1                                              [none]
# 2                                              [none]
# 3                                              [none]
# 4                                  [none, none, none]
# 5                                    [ductal, ductal]
# 6                                              [none]
# 7                                              [none]
# 8                                              [none]
# 9                                      [ductal, none]
# 10       [ductal, none, none, none, none, none, none]
# 11                                             [none]
# 12                                             [none]
# 13                                             [none]
# 14                        [none, lobular, none, none]
# 15                                             [none]
# 16    [ductal, none, lobular, none, none, none, none]
# 17                                             [none]
# 18                                             [none]
# 19                               [ductal, none, none]
# 20                                           [ductal]
# 21                                             [none]
# 22                      [ductal, none, lobular, none]
# 23                                             [none]
# 24                                       [none, none]
# 25                       [none, ductal, none, ductal]
# 26                                             [none]
# 27                                             [none]
# 28                                             [none]
# 29                                          [lobular]
# ...                                               ...
# 6989                                           [none]
# 6990                                           [none]
# 6991                                           [none]
# 6992                                           [none]
# 6993                                           [none]
# 6994                                           [none]
# 6995                                           [none]
# 6996                                           [none]
# 6997                                           [none]
# 6998                                           [none]
# 6999                                           [none]
# 7000                                           [none]
# 7001                                           [none]
# 7002                                           [none]
# 7003                                           [none]
# 7004                                           [none]
# 7005                                           [none]
# 7006                                           [none]
# 7007                                           [none]
# 7008                                           [none]
# 7009                                           [none]
# 7010                                           [none]
# 7011                                           [none]
# 7012                                           [none]
# 7013                                 [ductal, ductal]
# 7014                                         [ductal]
# 7015                                 [ductal, ductal]
# 7016     [ductal, lobular/ductal, none, ductal, none]
# 7017                                         [ductal]
# 7018                                         [ductal]
#
#                                       Summarized Labels
# 0                          {invasive lobular carcinoma}
# 1                                              {normal}
# 2                                              {normal}
# 3                                              {normal}
# 4                                              {normal}
# 5                           {invasive ductal carcinoma}
# 6                                                    {}
# 7                                              {normal}
# 8                                              {normal}
# 9                                              {normal}
# 10                            {benign ductal carcinoma}
# 11                                             {normal}
# 12                                             {normal}
# 13                                             {normal}
# 14                                             {normal}
# 15                                             {normal}
# 16                          {invasive ductal carcinoma}
# 17                                             {normal}
# 18                                             {normal}
# 19                          {invasive ductal carcinoma}
# 20                                             {normal}
# 21                                             {normal}
# 22    {benign lobular carcinoma, benign ductal carci...
# 23                                             {normal}
# 24                                             {normal}
# 25                            {benign ductal carcinoma}
# 26                                                   {}
# 27                                                   {}
# 28                                             {normal}
# 29                           {benign lobular carcinoma}
# ...                                                 ...
# 6989                                           {normal}
# 6990                                           {normal}
# 6991                                           {normal}
# 6992                                           {normal}
# 6993                                           {normal}
# 6994                                           {normal}
# 6995                                           {normal}
# 6996                                           {normal}
# 6997                                           {normal}
# 6998                                           {normal}
# 6999                                           {normal}
# 7000                                           {normal}
# 7001                                           {normal}
# 7002                                           {normal}
# 7003                                           {normal}
# 7004                                           {normal}
# 7005                                           {normal}
# 7006                                           {normal}
# 7007                                           {normal}
# 7008                                           {normal}
# 7009                                           {normal}
# 7010                                           {normal}
# 7011                                           {normal}
# 7012                                           {normal}
# 7013                        {invasive ductal carcinoma}
# 7014                          {benign ductal carcinoma}
# 7015                                           {normal}
# 7016                          {benign ductal carcinoma}
# 7017                          {benign ductal carcinoma}
# 7018                                           {normal}
#
# [7019 rows x 9 columns]

# %%
ts = []
for rep in split_reps["Path Report"]:
    ts.append(re.search("metast", rep))
split_reps[ts]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-5843d38990ac> in <module>()
#       2 for rep in split_reps["Path Report"]:
#       3     ts.append(re.search("metast", rep))
# ----> 4 split_reps[ts]
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: '[None None None ..., None None None] not in index'
